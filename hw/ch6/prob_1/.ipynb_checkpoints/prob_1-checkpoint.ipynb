# %% [markdown]
# # Problem 6.1
#
# In this problem we are asked to consider a homogeneous mixture of sodium and plutonium.  We will assume the only plutonium isotope is Pu-239 and natural sodium is used.  The Pu-239 fraction is 3 weight percent.  The overall mixture density is 1 g/cc.
#
# Question: what is the fuel utilization and $k_{\infty}$

# %%
import openmc

# %% [markdown]
# ## Materials

# %%
core = openmc.Material(name='core');
core.add_element('Na',0.97,'wo');
core.add_nuclide('Pu239',0.03,'wo');
core.set_density('g/cm3',1.0);

materials = openmc.Materials([core]);
materials.export_to_xml();

# %% [markdown]
# ## Geometry
# We will first model the geometry as a sphere with a reflective boundary

# %%
R = 5.0
core_g = openmc.Sphere(r=R,boundary_type='reflective');


core_c = openmc.Cell();
core_c.fill = core;
core_c.region = -core_g;

root_u = openmc.Universe();
root_u.add_cells([core_c]);

geometry = openmc.Geometry(root_u);

geometry.export_to_xml();

# %% [markdown]
# ## Tallies

# %%
cell_filter = openmc.CellFilter(core_c);


nu_tally = openmc.Tally(name='nu');
tally.scores = ['nu-fission']
tally.filters = [cell_filter];

abs_tally = openmc.Tally(name='abs');
abs_tally.scores = ['absorption']
abs_tally.nuclides = ['Pu239','Na23'];

fiss_tally = openmc.Tally(name='fission');
fiss_tally.scores = ['fission'];

tallies = openmc.Tallies([nu_tally,abs_tally,fiss_tally]);

tallies.export_to_xml();

# %% [markdown]
# ## Settings

# %%
settings = openmc.Settings();
settings.batches = 200;
settings.inactive = 50;
settings.particles = 10000;

bounds = [-R,-R,-R,R,R,R];
uniform_dist = openmc.stats.Box(bounds[:3],bounds[3:],
                                   only_fissionable=True);
settings.source = openmc.source.Source(space=uniform_dist);

settings.export_to_xml();

# %%
openmc.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                    | The OpenMC Monte Carlo Code
#          Copyright | 2011-2021 MIT and OpenMC contributors
#            License | https://docs.openmc.org/en/latest/license.html
#            Version | 0.12.1
#           Git SHA1 | d49e6ccb837685e399efdef8b29e46cdc693ccec
#          Date/Time | 2021-05-17 10:34:20
#     OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Na23 from /home/stu/OMC_DATA/endfb71_hdf5/Na23.h5
#  Reading Pu239 from /home/stu/OMC_DATA/endfb71_hdf5/Pu239.h5
#  Minimum neutron data temperature: 294.0 K
#  Maximum neutron data temperature: 294.0 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000.0 eV for Na23
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.56226
#         2/1    1.58036
#         3/1    1.53130
#         4/1    1.55862
#         5/1    1.57412
#         6/1    1.53795
#         7/1    1.55464
#         8/1    1.56105
#         9/1    1.54218
#        10/1    1.55398
#        11/1    1.56091
#        12/1    1.52561
#        13/1    1.56672
#        14/1    1.55141
#        15/1    1.56083
#        16/1    1.56086
#        17/1    1.54801
#        18/1    1.56123
#        19/1    1.57839
#        20/1    1.56734
#        21/1    1.57729
#        22/1    1.56789
#        23/1    1.58072
#        24/1    1.56723
#        25/1    1.55947
#        26/1    1.57902
#        27/1    1.55274
#        28/1    1.59068
#        29/1    1.56685
#        30/1    1.55390
#        31/1    1.54463
#        32/1    1.56205
#        33/1    1.56140
#        34/1    1.56648
#        35/1    1.57126
#        36/1    1.58204
#        37/1    1.54531
#        38/1    1.56289
#        39/1    1.57007
#        40/1    1.57739
#        41/1    1.56347
#        42/1    1.58138
#        43/1    1.56491
#        44/1    1.56325
#        45/1    1.58601
#        46/1    1.55522
#       165/1    1.59358    1.56724 +/- 0.00149
#       166/1    1.57875    1.56734 +/- 0.00148
#       167/1    1.58239    1.56747 +/- 0.00147
#       168/1    1.55726    1.56738 +/- 0.00146
#       169/1    1.58441    1.56752 +/- 0.00146
#       170/1    1.56782    1.56753 +/- 0.00144
#       171/1    1.55621    1.56743 +/- 0.00143
#       172/1    1.58077    1.56754 +/- 0.00143
#       173/1    1.57176    1.56758 +/- 0.00142
#       174/1    1.56640    1.56757 +/- 0.00140
#       175/1    1.55327    1.56745 +/- 0.00140
#       176/1    1.54499    1.56727 +/- 0.00140
#       177/1    1.52964    1.56698 +/- 0.00142
#       178/1    1.59625    1.56721 +/- 0.00142
#       179/1    1.57863    1.56730 +/- 0.00142
#       180/1    1.55199    1.56718 +/- 0.00141
#       181/1    1.58721    1.56733 +/- 0.00141
#       182/1    1.58107    1.56744 +/- 0.00140
#       183/1    1.57968    1.56753 +/- 0.00139
#       184/1    1.58289    1.56764 +/- 0.00139
#       185/1    1.58122    1.56774 +/- 0.00138
#       186/1    1.57642    1.56781 +/- 0.00137
#       187/1    1.56970    1.56782 +/- 0.00136
#       188/1    1.59050    1.56798 +/- 0.00136
#       189/1    1.57387    1.56803 +/- 0.00135
#       190/1    1.56900    1.56803 +/- 0.00134
#       191/1    1.56221    1.56799 +/- 0.00133
#       192/1    1.54798    1.56785 +/- 0.00133
#       193/1    1.57468    1.56790 +/- 0.00132
#       194/1    1.55358    1.56780 +/- 0.00132
#       195/1    1.57282    1.56783 +/- 0.00131
#       196/1    1.58517    1.56795 +/- 0.00131
#       197/1    1.56187    1.56791 +/- 0.00130
#       198/1    1.55350    1.56781 +/- 0.00129
#       199/1    1.56634    1.56780 +/- 0.00128
#       200/1    1.56025    1.56775 +/- 0.00128
#  Creating state point statepoint.200.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.8311e-01 seconds
#    Reading cross sections          = 1.7540e-01 seconds
#  Total time in simulation          = 6.8907e+01 seconds
#    Time in transport only          = 6.8530e+01 seconds
#    Time in inactive batches        = 1.0359e+01 seconds
#    Time in active batches          = 5.8548e+01 seconds
#    Time synchronizing fission bank = 1.8619e-01 seconds
#      Sampling source sites         = 1.5847e-01 seconds
#      SEND/RECV source sites        = 2.6974e-02 seconds
#    Time accumulating tallies       = 5.7839e-02 seconds
#    Time writing statepoints        = 5.8864e-03 seconds
#  Total time for finalization       = 1.0245e-04 seconds
#  Total time elapsed                = 6.9100e+01 seconds
#  Calculation Rate (inactive)       = 48265.0 particles/second
#  Calculation Rate (active)         = 25620.0 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.56741 +/- 0.00123
#  k-effective (Track-length)  = 1.56775 +/- 0.00128
#  k-effective (Absorption)    = 1.56765 +/- 0.00071
#  Combined k-effective        = 1.56760 +/- 0.00066
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %%
# !cat tallies.out
# Out:
#  ============================>     TALLY 1     <============================
#
#  Cell 1
#    Total Material
#      Nu-Fission Rate                      1.56775 +/- 0.00127712
