# %% [markdown]
# # Lab 6 - Analysis of Heterogeneous Reactors
# This is a big lab. For the first time we venture outside the territory for which diffusion theory analysis can be used.  This lab includes, what I think to be, a good variety of pratical "experimentation" to investigate the impact of heterogenaity on reactor core physics.
#
# This was also an opportunity for students to use the MCNP plotting features (which I had been avoiding due to the mild complexity of using the MCNP plot system in a Windows environment).
#
# The idea is to consider a reactor with light water moderator/coolant and low enriched uranium (metallic) fuel.  We will consider the following cases:
#
# a) homogeneous reactor with water, U-238 and U-235 all mixed together;
#
# b) A uranium metal fuel pin in a water tank (of the same size as the case above); the fuel pin is sized such that the *total* nuber of atoms of each isotope is unchanged; just arranged differently.
#
# c) An arrangement of 4 uranium metallic fuel pins; again the total number of atoms of each isotope is constant from the previous case;
#
# d) A 31x31 lattice of 2cm diameter pins (this will work out to be the same fuel mass and volume; this case is re-run with different lattice pitches. (2.5 cm; 3cm; 3.2cm; and 4cm - though I can pick more and more appropriate values for this analysis...)

# %% [markdown]
# ## Homogeneous mixture

# %%
import openmc
import openmc.model
import numpy as np
import os

# %% [markdown]
# Let's make a separte directory for each case so we can go back and look at the data

# %%
if (not os.path.isdir('./homogeneous')): #
    os.mkdir('./homogeneous');
os.chdir('./homogeneous');

# %% [markdown]
# ### Materials

# %%
h_core = openmc.Material(name='core');
h_core.add_nuclide('U238',0.70340,'wo');
h_core.add_nuclide('U235',0.007105,'wo');
h_core.add_nuclide('H1',0.03216,'wo');
h_core.add_nuclide('O16',0.2573,'wo');
h_core.add_s_alpha_beta('c_H_in_H2O');
h_core.set_density('g/cm3',3.06);

# %%
mf = openmc.Materials([h_core]);
mf.export_to_xml();

# %% [markdown]
# ### Geometry
# For the homogeneous case, the geometry is just a cylindrical tank 155 cm in height and 75 cm in radius.

# %%
core_tank = openmc.model.RightCircularCylinder([0.,0.,-5.],
                                              150.,radius=75.,
                                               axis='z',
                                              boundary_type='vacuum');

# %%
core_cell = openmc.Cell();
core_cell.fill = h_core;
core_cell.region = -core_tank;

root_universe = openmc.Universe();
root_universe.add_cells([core_cell]);

geometry = openmc.Geometry(root_universe);
geometry.export_to_xml();

# %% [markdown]
# ### Tallies
# Let's set up some tallies to keep track of absorption/capture/etc... in the fuel and moderator.

# %%
energy_filter = openmc.EnergyFilter([0.,0.625,20.e6]);
cell_filter = openmc.CellFilter([core_cell]);

tallies = openmc.Tallies()

t_abs = openmc.Tally(name='abs. tally');
t_abs.filters = [energy_filter,cell_filter];
t_abs.scores = ['absorption'];
t_abs.nuclides = ['H1','O16','U235','U238'];
tallies.append(t_abs);


t_fiss = openmc.Tally(name='fission tally');
t_fiss.filters = [energy_filter,cell_filter];
t_fiss.nuclides = ['U235','U238'];
t_fiss.scores = ['fission','nu-fission'];
tallies.append(t_fiss);

tallies.export_to_xml();

# %% [markdown]
# ### Settings
# (will want to add tallies later...)

# %%
settings = openmc.Settings();
settings.batches = 250;
settings.inactive = 100;
settings.particles = 10000;

bounds = [-75.,-75.,-5.,75.,75.,145.];
uniform_dist = openmc.stats.Box(bounds[:3],bounds[3:],
                               only_fissionable=True);
settings.source = openmc.source.Source(space=uniform_dist);

settings.export_to_xml();

# %%
openmc.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                    | The OpenMC Monte Carlo Code
#          Copyright | 2011-2021 MIT and OpenMC contributors
#            License | https://docs.openmc.org/en/latest/license.html
#            Version | 0.12.1
#           Git SHA1 | d49e6ccb837685e399efdef8b29e46cdc693ccec
#          Date/Time | 2021-05
#       239/1    0.89149    0.89207 +/- 0.00089
#       240/1    0.89461    0.89209 +/- 0.00088
#       241/1    0.89582    0.89211 +/- 0.00088
#       242/1    0.89648    0.89214 +/- 0.00087
#       243/1    0.90319    0.89222 +/- 0.00087
#       244/1    0.88720    0.89219 +/- 0.00086
#       245/1    0.88836    0.89216 +/- 0.00086
#       246/1    0.90744    0.89227 +/- 0.00086
#       247/1    0.88532    0.89222 +/- 0.00086
#       248/1    0.89478    0.89224 +/- 0.00085
#       249/1    0.90626    0.89233 +/- 0.00085
#       250/1    0.89567    0.89235 +/- 0.00084
#  Creating state point statepoint.250.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 2.6470e-01 seconds
#    Reading cross sections          = 2.3654e-01 seconds
#  Total time in simulation          = 2.4287e+01 seconds
#    Time in transport only          = 2.3638e+01 seconds
#    Time in inactive batches        = 2.8507e+00 seconds
#    Time in active batches          = 2.1436e+01 seconds
#    Time synchronizing fission bank = 1.3568e-01 seconds
#      Sampling source sites         = 1.1580e-01 seconds
#      SEND/RECV source sites        = 1.9252e-02 seconds
#    Time accumulating tallies       = 4.1996e-01 seconds
#    Time writing statepoints        = 4.5353e-03 seconds
#  Total time for finalization       = 1.1821e-04 seconds
#  Total time elapsed                = 2.4562e+01 seconds
#  Calculation Rate (inactive)       = 350793.0 particles/second
#  Calculation Rate (active)         = 69975.3 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.89242 +/- 0.00083
#  k-effective (Track-length)  = 0.89235 +/- 0.00084
#  k-effective (Absorption)    = 0.89169 +/- 0.00088
#  Combined k-effective        = 0.89210 +/- 0.00065
#  Leakage Fraction            = 0.03724 +/- 0.00019

# %% [markdown]
# The reported $k_{\text{eff}}$ of 0.89210 is slightly different than my MCNP result (0.88996).
#
# Further investigation revealed that in the MCNP output to which I'm comparing, I didn't use the thermal scattering treatment for the light water.  If I take out the s_alpha_beta from the OpenMC model the revised k_eff is 0.89051 which is closer to the same result.  Lesson learned (again!): that shit matters!

# %%
sp = openmc.StatePoint('statepoint.250.h5');
sp.tallies
# Out:
# {1: Tally
#  	ID             =	1
#  	Name           =	abs. tally
#  	Filters        =	EnergyFilter, CellFilter
#  	Nuclides       =	H1 O16 U235 U238
#  	Scores         =	['absorption']
#  	Estimator      =	tracklength,
#  2: Tally
#  	ID             =	2
#  	Name           =	fission tally
#  	Filters        =	EnergyFilter, CellFilter
#  	Nuclides       =	U235 U238
#  	Scores         =	['fission', 'nu-fission']
#  	Estimator      =	tracklength}

# %%
abs_rate = sp.get_tally(name='abs. tally');
ar_df = abs_rate.get_pandas_dataframe();
ar_df.head(10)
# Out:
#    energy low [eV]  energy high [eV]  cell nuclide       score      mean  \
# 0            0.000      6.250000e-01     1      H1  absorption  0.209772
# 1            0.000      6.250000e-01     1     O16  absorption  0.000061
# 2            0.000      6.250000e-01     1    U235  absorption  0.396307
# 3            0.000      6.250000e-01     1    U238  absorption  0.157535
# 4            0.625      2.000000e+07     1      H1  absorption  0.005354
# 5            0.625      2.000000e+07     1     O16  absorption  0.002373
# 6            0.625      2.000000e+07     1    U235  absorption  0.015828
# 7            0.625      2.000000e+07     1    U238  absorption  0.177426
#
#       std. dev.
# 0  2.119370e-04
# 1  6.115748e-08
# 2  4.039761e-04
# 3  1.589230e-04
# 4  3.762504e-06
# 5  8.649800e-06
# 6  1.170157e-05
# 7  2.680464e-04

# %%
total_abs = ar_df['mean'].sum();
print(f'Total absorption per source particle: %5.4f'%total_abs);
print(f'Leakage per source particle: %5.4f'%(1-total_abs));
# Out:
# Total absorption per source particle: 0.9647
# Leakage per source particle: 0.0353

# %% [markdown]
# This leakage percent is close to what MCNP gives (3.91%) - but, remember, the MCNP input (for some reason) did not include thermal scattering treatment.  (if I re-try this without thermal scattering treatment: I get leakage per source particle of 3.85% which is closer to the MCNP result - consistent.)

# %%
fiss_rate = sp.get_tally(name='fission tally');
fr_df = fiss_rate.get_pandas_dataframe();
fr_df.head(10)
# Out:
#    energy low [eV]  energy high [eV]  cell nuclide       score          mean  \
# 0            0.000      6.250000e-01     1    U235     fission  3.382861e-01
# 1            0.000      6.250000e-01     1    U235  nu-fission  8.243017e-01
# 2            0.000      6.250000e-01     1    U238     fission  9.847288e-07
# 3            0.000      6.250000e-01     1    U238  nu-fission  2.454031e-06
# 4            0.625      2.000000e+07     1    U235     fission  1.060416e-02
# 5            0.625      2.000000e+07     1    U235  nu-fission  2.597723e-02
# 6            0.625      2.000000e+07     1    U238     fission  1.497145e-02
# 7            0.625      2.000000e+07     1    U238  nu-fission  4.207021e-02
#
#       std. dev.
# 0  3.449188e-04
# 1  8.404637e-04
# 2  9.940261e-10
# 3  2.477200e-09
# 4  7.689840e-06
# 5  1.874295e-05
# 6  1.649006e-05
# 7  4.868483e-05

# %%
fiss = fr_df[fr_df['score']=='fission'];
total_fission = fiss['mean'].sum()
print(f'Total fission: %5.4f per source particle'%total_fission);
# Out:
# Total fission: 0.3639 per source particle

# %%
fiss.head()
# Out:
#    energy low [eV]  energy high [eV]  cell nuclide    score          mean  \
# 0            0.000      6.250000e-01     1    U235  fission  3.382861e-01
# 2            0.000      6.250000e-01     1    U238  fission  9.847288e-07
# 4            0.625      2.000000e+07     1    U235  fission  1.060416e-02
# 6            0.625      2.000000e+07     1    U238  fission  1.497145e-02
#
#       std. dev.
# 0  3.449188e-04
# 2  9.940261e-10
# 4  7.689840e-06
# 6  1.649006e-05

# %% [markdown]
# I'm sure a lot more can be done here, but I want to move on to the next case, for now.

# %%
os.chdir('..')
if (not os.path.isdir('./one_pin')): #
    os.mkdir('./one_pin');
os.chdir('./one_pin');

# %% [markdown]
# ## One Pin
# Here I will collect all of the uranium in the homogeneous core mixture and combine into a single pin.  This pin will be placed into a tank of water the same size as before

# %% [markdown]
# ### Material

# %%
fuel = openmc.Material(name='fuel');
fuel.add_nuclide('U238',0.99,'wo');
fuel.add_nuclide('U235',0.01,'wo');
fuel.set_density('g/cm3',19.1);

mod = openmc.Material(name='mod');
mod.add_nuclide('H1',2,'ao');
mod.add_nuclide('O16',1,'ao');
mod.add_s_alpha_beta('c_H_in_H2O');
mod.set_density('g/cm3',1.0);

mf = openmc.Materials();
mf += [fuel,mod];

mf.export_to_xml();

# %% [markdown]
# ### Geometry
# The fuel pin is a rcc 100 cm high and 31 cm in radius.  This sits inside the larger cylindrical tank (same dimensions of the homogeneous core) already defined as "core_tank"

# %%
fuel_pin = openmc.model.RightCircularCylinder([0.,0.,0.],
                                              100.,radius=31.,
                                               axis='z');

fuel_cell = openmc.Cell();
fuel_cell.fill = fuel;
fuel_cell.region = -fuel_pin;

rx_tank = openmc.Cell();
rx_tank.fill = mod;
rx_tank.region = +fuel_pin & -core_tank;

root = openmc.Universe();
root.add_cells([fuel_cell,rx_tank]);

geometry = openmc.Geometry();
geometry.root_universe = root;

geometry.export_to_xml();

# %% [markdown]
# ### Tallies
# I will use the same tallies but I'll need to change the cell filters for the current geometry so some adjustment to the objects will be required.

# %%
#energy_filter = openmc.EnergyFilter([0.,0.625,20.e6]); #<-- keep this for reference

fuel_cell_filter = openmc.CellFilter([fuel_cell]);
rx_tank_cell_filter = openmc.CellFilter([rx_tank]);

tallies = openmc.Tallies()

abs_fuel = openmc.Tally(name='abs. fuel');
abs_fuel.filters = [energy_filter,fuel_cell_filter];
abs_fuel.scores = ['absorption'];
abs_fuel.nuclides = ['U235','U238'];
tallies.append(abs_fuel);

abs_mod = openmc.Tally(name='abs. mod');
abs_mod.filters = [energy_filter,rx_tank_cell_filter];
abs_mod.nuclides = ['H1','O16'];
abs_mod.scores = ['absorption'];
tallies.append(abs_mod);



t_fiss = openmc.Tally(name='fission tally');
t_fiss.filters = [energy_filter,fuel_cell_filter];
t_fiss.nuclides = ['U235','U238'];
t_fiss.scores = ['fission','nu-fission'];
tallies.append(t_fiss);

tallies.export_to_xml();

# %% [markdown]
# ### Settings
# I will use mostly the same settings.  I just want to change the bounding box so it now only encompases the fuel region.  Probably not strictly required but anyway...

# %%
bounds = [-31.,-31.,0.,31.,31.,100.];
uniform_dist = openmc.stats.Box(bounds[:3],bounds[3:],
                               only_fissionable=True);
settings.source = openmc.source.Source(space=uniform_dist);

settings.export_to_xml();

# %%
openmc.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                    | The OpenMC Monte Carlo Code
#          Copyright | 2011-2021 MIT and OpenMC contributors
#            License | https://docs.openmc.org/en/latest/license.html
#            Version | 0.12.1
#           Git SHA1 | d49e6ccb837685e399efdef8b29e46cdc693ccec
#          Date/Time | 2021-05-10 07:24:45
#     OpenMP Threads | 36
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading U238 from /home/sblair/OMC_DATA/endfb71_hdf5/U238.h5
#  Reading U235 from /home/sblair/OMC_DATA/endfb71_hdf5/U235.h5
#  Reading H1 from /home/sblair/OMC_DATA/endfb71_hdf5/H1.h5
#  Reading O16 from /home/sblair/OMC_DATA/endfb71_hdf5/O16.h5
#  Reading c_H_in_H2O from /home/sblair/OMC_DATA/endfb71_hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294.0 K
#  Maximum neutron data temperature: 294.0 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000.0 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.53768
#         2/1    0.53307
#         3/1    0.51529
#         4/1    0.53205
#         5/1    0.52295
#         6/1    0.52746
#         7/1    0.52723
#         8/1    0.52202
#         9/1    0.50745
#        10/1    0.51796
#        11/1    0.52114
#        12/1    0.53076
#        13/1    0.53142
#        14/1    0.52876
#        15/1    0.52637
#        16/1    0.52693
#        17/1    0.50745
#        18/1    0.52894
#        19/1    0.52650
#        20/1    0.50587
#        21/1    0.53065
#        22/1    0.53252
#        23/1    0.51683
#        24/1    0.52433
#        25/1    0.52169
#        26/1    0.51738
#        27/1    0.51591
#        28/1    0.50800
#        29/1    0.52728
#        30/1    0.52277
#        31/1    0.52758
#        32/1    0.51384
#        33/1    0.51677
#        34/1    0.51853
#        35/1    0.51888
#        36/1    0.52607
#        37/1    0.52453
#        38/1    0.52674
#        39/1    0.51589
#        40/1    0.54278
#        41/1    0.53344
#        42/1    0.52855
#        43/1    0.53245
#        44/1    0.52420
#        45/1    0.52265
#        46/1    0.51873
#        47/1    0.52062
#        48/1    0.51232
#        49/1    0.51592
#        50/1    0.51737
#        51/1    0.52583
#        52/1    0.51930
#        53/1    0.54376
#        54/1    0.52715
#        55/1    0.51780
#        56/1    0.53347
#        57/1    0.51627
#        58/1    0.51023
#        59/1    0.54011
#        60/1    0.52556
#        61/1    0.52085
#        62/1    0.53371
particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.52438 +/- 0.00056
#  k-effective (Track-length)  = 0.52473 +/- 0.00063
#  k-effective (Absorption)    = 0.52428 +/- 0.00074
#  Combined k-effective        = 0.52436 +/- 0.00051
#  Leakage Fraction            = 0.02218 +/- 0.00023

# %% [markdown]
# The result is much closer to the MCNP result (why?).  The main difference from the homgeneous case is an increase in neutron capture.  S
#
# The tallies will now be analyzed to determine:
# a) where does most of the neutron capture occur;
# b) in which nuclide; and
# c) at what energy

# %%
sp = openmc.StatePoint('statepoint.250.h5');
sp.tallies
# Out:
# {3: Tally
#  	ID             =	3
#  	Name           =	abs. fuel
#  	Filters        =	EnergyFilter, CellFilter
#  	Nuclides       =	U235 U238
#  	Scores         =	['absorption']
#  	Estimator      =	tracklength,
#  4: Tally
#  	ID             =	4
#  	Name           =	abs. mod
#  	Filters        =	EnergyFilter, CellFilter
#  	Nuclides       =	H1 O16
#  	Scores         =	['absorption']
#  	Estimator      =	tracklength,
#  5: Tally
#  	ID             =	5
#  	Name           =	fission tally
#  	Filters        =	EnergyFilter, CellFilter
#  	Nuclides       =	U235 U238
#  	Scores         =	['fission', 'nu-fission']
#  	Estimator      =	tracklength}

# %%
abs_fuel = sp.get_tally(name='abs. fuel');
abs_fuel_df = abs_fuel.get_pandas_dataframe();
abs_fuel_df.head(10)
# Out:
#    energy low [eV]  energy high [eV]  cell nuclide       score      mean  \
# 0            0.000      6.250000e-01     2    U235  absorption  0.092862
# 1            0.000      6.250000e-01     2    U238  absorption  0.038763
# 2            0.625      2.000000e+07     2    U235  absorption  0.052870
# 3            0.625      2.000000e+07     2    U238  absorption  0.428358
#
#    std. dev.
# 0   0.000261
# 1   0.000110
# 2   0.000104
# 3   0.000530

# %%
abs_mod = sp.get_tally(name='abs. mod');
abs_mod_df = abs_mod.get_pandas_dataframe();
abs_mod_df.head(10)
# Out:
#    energy low [eV]  energy high [eV]  cell nuclide       score      mean  \
# 0            0.000      6.250000e-01     3      H1  absorption  0.364923
# 1            0.000      6.250000e-01     3     O16  absorption  0.000104
# 2            0.625      2.000000e+07     3      H1  absorption  0.003477
# 3            0.625      2.000000e+07     3     O16  absorption  0.000695
#
#       std. dev.
# 0  5.715463e-04
# 1  1.635823e-07
# 2  4.191605e-06
# 3  6.255310e-06

# %% [markdown]
# A brief glance at the above results indicate that the vast majority of the absorptions are happeinging:
# a) epithermal and fast neutrons in U238; and
# b) thermal neutrons in H1 in the moderator.

# %%
os.chdir('..')
if (not os.path.isdir('./four_pins')): #
    os.mkdir('./four_pins');
os.chdir('./four_pins');

# %% [markdown]
# ## 4-Pins
# In this iteration we divide the 1 large pin into 4 equally sized pins that, cumulatively, has the same volume as the single pin.  In making this change we should see a reduction in capture in U-238 but - well, let's just do it and find out for sure.  While we're at it, we will practice making lattices in OpenMC, practice plotting the geometry, and learn how to do tallies in lattices.

# %% [markdown]
# ### Materials
#
# There are no changes to the materials for this part of the project so we will merely export the existing materials object to xml.

# %%
# no changes; create a local copy of the xml file.
mf.export_to_xml();

# reminder the two materials are:
# fuel - 1% enriched uranium fuel 
# mod - light water moderator

# %% [markdown]
# ### Geometry
# I will make a 2x2 lattice of the fuel pins.  The lattice pitch is 38 cm; the entire area is in a RPP centered on the origin that is 76 cm square and 100 cm tall.

# %%
pitch = 38; #cm
fuel_radius = 15.5; #cm

# create a RCC for a generic fuel pin in the fuel pin universe

fuel_pin = openmc.model.RightCircularCylinder([0.,0.,0.],100.,
                                              radius=fuel_radius,
                                              axis='z');

fp_fuel = openmc.Cell(name='fuel');
fp_fuel.fill = fuel;
fp_fuel.region = -fuel_pin;

fp_mod = openmc.Cell(name='mod in fuel');
fp_mod.fill = mod;
fp_mod.region = +fuel_pin;

fp = openmc.Universe();
fp.add_cells((fp_fuel,fp_mod));

mod_cell = openmc.Cell();
mod_cell.fill = mod;

all_water = openmc.Universe();
all_water.add_cell(mod_cell);

# %%
colors = {}
colors[mod] = 'blue';
colors[fuel] = 'yellow';

# %%
# let's make some other plots
main = openmc.Cell();
main.fill = fp;

root = openmc.Universe();
root.add_cell(main);

g = openmc.Geometry();
g.root_universe = root;
g.export_to_xml();

# %%
p = openmc.Plot();
p.width = [pitch,pitch];
p.pixels = [400,400];
p.origin = [0.,0.,10.];
#p.basis = 'xy';
p.color_by = 'material';
p.colors = colors

openmc.plot_inline(p);

# %%
# maybe you don't really need this?
core_area = openmc.model.RectangularParallelepiped(-38.,38.,-38.,38.,
                                                  0.,100.);

lattice = openmc.RectLattice();
lattice.dimension = [2,2];
lattice.lower_left = [-pitch,-pitch];
lattice.pitch = [pitch,pitch];

lattice.universes = [
    [fp,fp],
    [fp,fp]
];

lattice.outer = all_water;

core_cell = openmc.Cell();
core_cell.fill = lattice;
core_cell.region = -core_area;

refl_cell = openmc.Cell();
refl_cell.fill = mod;
refl_cell.region = +core_area & -core_tank;



#main = openmc.Cell()
#main.fill = lattice;

root = openmc.Universe();
root.add_cells([core_cell,refl_cell]);

g = openmc.Geometry();
g.root_universe = root;
g.export_to_xml();

# %% [markdown]
# I think this should all "work" -- even if it's not the best thing ever written.  To be sure, it's a good idea to make a plot to be sure

# %%
colors = {}
colors[mod] = 'blue';
colors[fuel] = 'yellow';

# %%
p = openmc.Plot();
p.width = [4*pitch,4*pitch];
p.origin = [0.,0.,10.];
p.pixels = [400,400];
p.color_by = 'material';
p.colors = colors

openmc.plot_inline(p);

# %% [markdown]
# Okay...this looks correct now.

# %%
fuel_cell_filter = openmc.DistribcellFilter([fp_fuel]);
mod_in_fuel_filter = openmc.DistribcellFilter([fp_mod]);
rfl_cell_filter = openmc.CellFilter([refl_cell]);

tallies = openmc.Tallies()

abs_fuel = openmc.Tally(name='abs. fuel');
abs_fuel.filters = [energy_filter,fuel_cell_filter];
abs_fuel.scores = ['absorption'];
abs_fuel.nuclides = ['U235','U238'];
tallies.append(abs_fuel);

abs_mod_ref = openmc.Tally(name='abs. mod refl');
abs_mod_ref.filters = [energy_filter,rfl_cell_filter];
abs_mod_ref.nuclides = ['H1','O16'];
abs_mod_ref.scores = ['absorption'];
tallies.append(abs_mod_ref);

abs_mod_fuel = openmc.Tally(name='abs. mod fuel');
abs_mod_fuel.filters = [energy_filter,mod_in_fuel_filter];
abs_mod_fuel.nuclides = ['H1','O16'];
abs_mod_fuel.scores = ['absorption'];
tallies.append(abs_mod_fuel);


t_fiss = openmc.Tally(name='fission tally');
t_fiss.filters = [energy_filter,fuel_cell_filter];
t_fiss.nuclides = ['U235','U238'];
t_fiss.scores = ['fission','nu-fission'];
tallies.append(t_fiss);

tallies.export_to_xml();

settings.export_to_xml();

# %%
openmc.run();
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                    | The OpenMC Monte Carlo Code
#          Copyright | 2011-2021 MIT and OpenMC contributors
#            License | https://docs.openmc.org/en/latest/license.html
#            Version | 0.12.1
#           Git SHA1 | d49e6ccb837685e399efdef8b29e46cdc693ccec
#          Date/Time | 2021-05-10 07:25:10
#     OpenMP Threads | 36
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading U238 from /home/sblair/OMC_DATA/endfb71_hdf5/U238.h5
#  Reading U235 from /home/sblair/OMC_DATA/endfb71_hdf5/U235.h5
#  Reading H1 from /home/sblair/OMC_DATA/endfb71_hdf5/H1.h5
#  Reading O16 from /home/sblair/OMC_DATA/endfb71_hdf5/O16.h5
#  Reading c_H_in_H2O from /home/sblair/OMC_DATA/endfb71_hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294.0 K
#  Maximum neutron data temperature: 294.0 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000.0 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0
#       242/1    0.59426    0.60048 +/- 0.00088
#       243/1    0.58848    0.60040 +/- 0.00088
#       244/1    0.59107    0.60034 +/- 0.00087
#       245/1    0.59224    0.60028 +/- 0.00087
#       246/1    0.60037    0.60028 +/- 0.00086
#       247/1    0.59790    0.60026 +/- 0.00086
#       248/1    0.59520    0.60023 +/- 0.00085
#       249/1    0.59419    0.60019 +/- 0.00085
#       250/1    0.59587    0.60016 +/- 0.00084
#  Creating state point statepoint.250.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 2.6598e-01 seconds
#    Reading cross sections          = 2.3889e-01 seconds
#  Total time in simulation          = 1.6469e+01 seconds
#    Time in transport only          = 1.5702e+01 seconds
#    Time in inactive batches        = 5.2945e+00 seconds
#    Time in active batches          = 1.1175e+01 seconds
#    Time synchronizing fission bank = 1.4770e-01 seconds
#      Sampling source sites         = 1.2742e-01 seconds
#      SEND/RECV source sites        = 1.9653e-02 seconds
#    Time accumulating tallies       = 5.1878e-01 seconds
#    Time writing statepoints        = 5.9075e-03 seconds
#  Total time for finalization       = 2.3759e-04 seconds
#  Total time elapsed                = 1.6746e+01 seconds
#  Calculation Rate (inactive)       = 188875.0 particles/second
#  Calculation Rate (active)         = 134233.0 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.59946 +/- 0.00078
#  k-effective (Track-length)  = 0.60016 +/- 0.00084
#  k-effective (Absorption)    = 0.60054 +/- 0.00078
#  Combined k-effective        = 0.60004 +/- 0.00066
#  Leakage Fraction            = 0.01598 +/- 0.00015

# %% [markdown]
# Once again; this is much like the MCNP result.

# %%
sp = openmc.StatePoint('statepoint.250.h5');
sp.tallies
# Out:
# {6: Tally
#  	ID             =	6
#  	Name           =	abs. fuel
#  	Filters        =	EnergyFilter, DistribcellFilter
#  	Nuclides       =	U235 U238
#  	Scores         =	['absorption']
#  	Estimator      =	tracklength,
#  7: Tally
#  	ID             =	7
#  	Name           =	abs. mod refl
#  	Filters        =	EnergyFilter, CellFilter
#  	Nuclides       =	H1 O16
#  	Scores         =	['absorption']
#  	Estimator      =	tracklength,
#  8: Tally
#  	ID             =	8
#  	Name           =	abs. mod fuel
#  	Filters        =	EnergyFilter, DistribcellFilter
#  	Nuclides       =	H1 O16
#  	Scores         =	['absorption']
#  	Estimator      =	tracklength,
#  9: Tally
#  	ID             =	9
#  	Name           =	fission tally
#  	Filters        =	EnergyFilter, DistribcellFilter
#  	Nuclides       =	U235 U238
#  	Scores         =	['fission', 'nu-fission']
#  	Estimator      =	tracklength}

# %%
abs_fuel = sp.get_tally(name='abs. fuel');
abs_fuel_df = abs_fuel.get_pandas_dataframe();
#abs_fuel_df.head(25)

# %%
u235_abs = abs_fuel_df[(abs_fuel_df['nuclide']=='U235')]['mean'].sum()
print(f'Absorptioni in U235: %5.4f'%u235_abs);
# Out:
# Absorptioni in U235: 0.1905

# %%
u238_abs = abs_fuel_df[abs_fuel_df['nuclide']=='U238']['mean'].sum()
print(f'Absorptioni in U238: %5.4f'%u238_abs);
# Out:
# Absorptioni in U238: 0.3844

# %%
abs_mod_refl = sp.get_tally(name='abs. mod refl');
abs_mod_refl_df = abs_mod_refl.get_pandas_dataframe();
abs_mod_refl_df.head(25)
# Out:
#    energy low [eV]  energy high [eV]  cell nuclide       score      mean  \
# 0            0.000      6.250000e-01     9      H1  absorption  0.116528
# 1            0.000      6.250000e-01     9     O16  absorption  0.000033
# 2            0.625      2.000000e+07     9      H1  absorption  0.000778
# 3            0.625      2.000000e+07     9     O16  absorption  0.000181
#
#       std. dev.
# 0  3.999647e-04
# 1  1.144743e-07
# 2  2.819935e-06
# 3  3.078471e-06

# %%
total_abs_mod_refl = abs_mod_refl_df['mean'].sum();
print(f'total absorption in moderator in reflector region: %5.4f'%total_abs_mod_refl);
# Out:
# total absorption in moderator in reflector region: 0.1175

# %%
abs_mod_fuel = sp.get_tally(name='abs. mod fuel');
abs_mod_fuel_df = abs_mod_fuel.get_pandas_dataframe();
#abs_mod_fuel_df.head(25)

# %%
total_abs_mod_fuel = abs_mod_fuel_df['mean'].sum()
print(f'total absorption in the moderator in the core region: %5.4f'%total_abs_mod_fuel);
# Out:
# total absorption in the moderator in the core region: 0.2948

# %%
total_mod_abs = total_abs_mod_fuel+total_abs_mod_refl;
print(f'total absorption in moderator material: %5.4f'%total_mod_abs);
# Out:
# total absorption in moderator material: 0.4123

# %%
fiss = sp.get_tally(name='fission tally');
fiss_df = fiss.get_pandas_dataframe();
#fiss_df.head(25)

# %%
fission = fiss_df[fiss_df['score']=='fission'];
#fission.head(10)

# %%
fiss_235 = fission[fission['nuclide']=='U235'];
fiss_238 = fission[fission['nuclide']=='U238'];
fiss_235.head(10)
# Out:
#    energy low [eV] energy high [eV] level 1      level 2       level 3       \
#                                        univ cell     lat          univ cell
#                                          id   id      id  x  y      id   id
# 0            0.000     6.250000e-01       7    8       6  0  0       3    4
# 4            0.000     6.250000e-01       7    8       6  1  0       3    4
# 8            0.000     6.250000e-01       7    8       6  0  1       3    4
# 12           0.000     6.250000e-01       7    8       6  1  1       3    4
# 16           0.625     2.000000e+07       7    8       6  0  0       3    4
# 20           0.625     2.000000e+07       7    8       6  1  0       3    4
# 24           0.625     2.000000e+07       7    8       6  0  1       3    4
# 28           0.625     2.000000e+07       7    8       6  1  1       3    4
#
#    distribcell nuclide    score      mean std. dev.
#
#
# 0            0    U235  fission  0.030679  0.000182
# 4            1    U235  fission  0.031721  0.000177
# 8            2    U235  fission  0.029596  0.000192
# 12           3    U235  fission  0.030602  0.000173
# 16           0    U235  fission  0.008758  0.000053
# 20           1    U235  fission  0.009211  0.000054
# 24           2    U235  fission  0.008540  0.000047
# 28           3    U235  fission  0.008753  0.000051

# %%
fiss_238.head(10)
# Out:
#    energy low [eV] energy high [eV] level 1      level 2       level 3       \
#                                        univ cell     lat          univ cell
#                                          id   id      id  x  y      id   id
# 2            0.000     6.250000e-01       7    8       6  0  0       3    4
# 6            0.000     6.250000e-01       7    8       6  1  0       3    4
# 10           0.000     6.250000e-01       7    8       6  0  1       3    4
# 14           0.000     6.250000e-01       7    8       6  1  1       3    4
# 18           0.625     2.000000e+07       7    8       6  0  0       3    4
# 22           0.625     2.000000e+07       7    8       6  1  0       3    4
# 26           0.625     2.000000e+07       7    8       6  0  1       3    4
# 30           0.625     2.000000e+07       7    8       6  1  1       3    4
#
#    distribcell nuclide    score          mean     std. dev.
#
#
# 2            0    U238  fission  9.320505e-08  5.467000e-10
# 6            1    U238  fission  9.640370e-08  5.423423e-10
# 10           2    U238  fission  8.994923e-08  5.844830e-10
# 14           3    U238  fission  9.297731e-08  5.259288e-10
# 18           0    U238  fission  1.909125e-02  9.100600e-05
# 22           1    U238  fission  2.016065e-02  9.788008e-05
# 26           2    U238  fission  1.845580e-02  9.566383e-05
# 30           3    U238  fission  1.913616e-02  9.113569e-05

# %%
print(f'fission in U238: %5.4f'%fiss_238['mean'].sum());
# Out:
# fission in U238: 0.0768

# %%
print(f'fission in U235: %5.4f'%fiss_235['mean'].sum());
# Out:
# fission in U235: 0.1579

# %%
os.chdir('..')
if (not os.path.isdir('./31x31_pins')): #
    os.mkdir('./31x31_pins');
os.chdir('./31x31_pins');

# %% [markdown]
# ## 31x31 lattices
# For this section all of the materials, tallies, and settings can remain the same; the geometry will need to be updated to conver the 2x2 lattice of thick rods into a 31x31 lattice of much thinner rods of the same total volume.  We will start by defining a function that creates a new geometry with user input for pitch

# %%
def gen_lattice(l_pitch):
    #input lattice pitch
    
    n_pins = 31;
    pin_r = 1.; # cm, fuel pin radius
    
    fuel_pin = openmc.model.RightCircularCylinder([0.,0.,0.],100.,
                                              radius=pin_r,
                                              axis='z');

    fp_fuel = openmc.Cell(name='fuel');
    fp_fuel.fill = fuel;
    fp_fuel.region = -fuel_pin;

    fp_mod = openmc.Cell(name='mod in fuel');
    fp_mod.fill = mod;
    fp_mod.region = +fuel_pin;

    fp = openmc.Universe();
    fp.add_cells((fp_fuel,fp_mod));

    mod_cell = openmc.Cell();
    mod_cell.fill = mod;

    all_water = openmc.Universe();
    all_water.add_cell(mod_cell);
    core_bd = l_pitch*n_pins/2.
    core_area = openmc.model.RectangularParallelepiped(-core_bd,core_bd,-core_bd,core_bd,
                                                  0.,100.);

    lattice = openmc.RectLattice();
    lattice.dimension = [n_pins,n_pins];
    lattice.lower_left = [-core_bd,-core_bd];
    lattice.pitch = [l_pitch,l_pitch];

    lattice.universes = [[ fp for i in range(n_pins)]for j in range(n_pins)];
           

    lattice.outer = all_water;

    core_cell = openmc.Cell();
    core_cell.fill = lattice;
    core_cell.region = -core_area;

    refl_cell = openmc.Cell();
    refl_cell.fill = mod;
    refl_cell.region = +core_area & -core_tank;

    root = openmc.Universe();
    root.add_cells([core_cell,refl_cell]);

    g = openmc.Geometry();
    g.root_universe = root;
    g.export_to_xml();
    
    
    fuel_cell_filter = openmc.DistribcellFilter([fp_fuel]);
    mod_in_fuel_filter = openmc.DistribcellFilter([fp_mod]);
    rfl_cell_filter = openmc.CellFilter([refl_cell]);

    tallies = openmc.Tallies()

    abs_fuel = openmc.Tally(name='abs. fuel');
    abs_fuel.filters = [energy_filter,fuel_cell_filter];
    abs_fuel.scores = ['absorption'];
    abs_fuel.nuclides = ['U235','U238'];
    tallies.append(abs_fuel);

    abs_mod_ref = openmc.Tally(name='abs. mod refl');
    abs_mod_ref.filters = [energy_filter,rfl_cell_filter];
    abs_mod_ref.nuclides = ['H1','O16'];
    abs_mod_ref.scores = ['absorption'];
    tallies.append(abs_mod_ref);

    abs_mod_fuel = openmc.Tally(name='abs. mod fuel');
    abs_mod_fuel.filters = [energy_filter,mod_in_fuel_filter];
    abs_mod_fuel.nuclides = ['H1','O16'];
    abs_mod_fuel.scores = ['absorption'];
    tallies.append(abs_mod_fuel);


    t_fiss = openmc.Tally(name='fission tally');
    t_fiss.filters = [energy_filter,fuel_cell_filter];
    t_fiss.nuclides = ['U235','U238'];
    t_fiss.scores = ['fission','nu-fission'];
    tallies.append(t_fiss);

    tallies.export_to_xml();

# %%
# generate the first geometry and make a plot
if (not os.path.isdir('./p2_5')): #
    os.mkdir('./p2_5');
os.chdir('./p2_5');


mf.export_to_xml();
settings.export_to_xml();
gen_lattice(2.5);
# do without extra tallies for now.

p = openmc.Plot();
p.width = [200., 200.];
p.origin = [0.,0.,10.];
p.pixels = [1024,1024];
p.color_by = 'material';
p.colors = colors

openmc.plot_inline(p);

# %%
openmc.run();
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                    | The OpenMC Monte Carlo Code
#          Copyright | 2011-2021 MIT and OpenMC contributors
#            License | https://docs.openmc.org/en/latest/license.html
#            Version | 0.12.1
#           Git SHA1 | d49e6ccb837685e399efdef8b29e46cdc693ccec
#          Date/Time | 2021-05-10 07:25:27
#     OpenMP Threads | 36
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading U238 from /home/sblair/OMC_DATA/endfb71_hdf5/U238.h5
#  Reading U235 from /home/sblair/OMC_DATA/endfb71_hdf5/U235.h5
#  Reading H1 from /home/sblair/OMC_DATA/endfb71_hdf5/H1.h5
#  Reading O16 from /home/sblair/OMC_DATA/endfb71_hdf5/O16.h5
#  Reading c_H_in_H2O from /home/sblair/OMC_DATA/endfb71_hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294.0 K
#  Maximum neutron data temperature: 294.0 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000.0 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.99339
#         2/1    0.95795
#         3/1    0.95433
#         4/1    0.96225
#         5/1    0.93931
#         6/1    0.96652
#         7/1    0.95559
#         8/1    0.95267
#         9/1    0.96829
#        10/1    0.94587
#        11/1    0.96447
#        12/1    0.95092
#        13/1    0.97715
#        14/1    0.93628
#        15/1    0.97978
#        16/1    0.97457
#        17/1    0.96843
#        18/1    0.97021
#        19/1    0.98053
#        20/1    0.94343
#        21/1    0.98184
#        22/1    0.93675
#        23/1    0.97057
#        24/1    0.96324
#        25/1    0.96842
#        26/1    0.95282
#        27/1    0.97118
#        28/1    0.96606
#        29/1    0.96538
#        30/1    0.97403
#        31/1    0.96865
#        32/1    0.96933
#        33/1    0.96043
#        34/1    0.95100
#        35/1    0.95678
#        36/1    0.95053
#        37/1    0.97243
#        38/1    0.96605
#        39/1    0.96346
#        40/1    0.97814
#        41/1    0.96827
#        42/1    0.97235
#        43/1    0.95187
#        44/1    0.96245
#        45/1    0.97271
#        46/1    0.95202
#        47/1    0.95671
#        48/1    0.95989
#        49/1    0.97942
#        50/1    0.97280
#        51/1    0.95879
#        52/1    0.97683
#        53/1    0.97691
#        54/1    0.98158
#        55/1    0.96654
#        56/1    1.00053
#        57/1    0.97841
#        58/1    0.95470
#        59/1    0.97927
#        60/1    0.95195
#        61/1    0.96166
#        62/1    0.96110
#        63/1    0.94692
#        64/1    0.95731
#        65/1    0.95349
#        66/1    0.98545
#        67/1    0.92693
#        68/1    0.96945
#        69/1    0.94648
#        70/1    0.96389
#        71/1    0.96755
#        72/1    0.95012
#        73/1    0.95870
#        74/1    0.95737
#        75/1    0.95890
#        76/1    0.95783
#        77/1    0.95526
#        78/1    0.96753
#        79/1    0.96562
#        80/1    0.96078
#        81/1    0.95710
#        82/1    0.93396
#        83/1    0.97423
#        84/1    0.94847
#        85/1    0.96619
#        86/1    0.97272
#        87/1    0.94782
#        88/1    0.95766
#        89/1    0.94515
#        90/1    0.96753
#        91/1    0.97980
#        92/1    0.94722
#        93/1    0.94137
#        94/1    0.98633
#        95/1    0.95539
#        96/1    0.97641
#        97/1    0.94924
#       222/1    0.96379    0.96597 +/- 0.00110
#       223/1    0.97908    0.96608 +/- 0.00109
#       224/1    0.97136    0.96612 +/- 0.00109
#       225/1    0.96398    0.96610 +/- 0.00108
#       226/1    0.98064    0.96622 +/- 0.00108
#       227/1    0.95658    0.96614 +/- 0.00107
#       228/1    0.96801    0.96616 +/- 0.00106
#       229/1    0.97849    0.96625 +/- 0.00106
#       230/1    0.94522    0.96609 +/- 0.00106
#       231/1    0.94826    0.96595 +/- 0.00106
#       232/1    0.94646    0.96581 +/- 0.00106
#       233/1    0.96596    0.96581 +/- 0.00106
#       234/1    0.94967    0.96569 +/- 0.00106
#       235/1    0.95403    0.96560 +/- 0.00105
#       236/1    0.96760    0.96562 +/- 0.00104
#       237/1    0.95851    0.96556 +/- 0.00104
#       238/1    0.96966    0.96559 +/- 0.00103
#       239/1    0.98875    0.96576 +/- 0.00104
#       240/1    0.97343    0.96582 +/- 0.00103
#       241/1    0.97281    0.96586 +/- 0.00102
#       242/1    0.94896    0.96575 +/- 0.00102
#       243/1    0.96635    0.96575 +/- 0.00102
#       244/1    0.96798    0.96577 +/- 0.00101
#       245/1    0.96539    0.96576 +/- 0.00100
#       246/1    0.95443    0.96569 +/- 0.00100
#       247/1    0.95941    0.96564 +/- 0.00099
#       248/1    0.96167    0.96562 +/- 0.00099
#       249/1    0.97072    0.96565 +/- 0.00098
#       250/1    0.94760    0.96553 +/- 0.00098
#  Creating state point statepoint.250.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 2.5593e-01 seconds
#    Reading cross sections          = 2.2973e-01 seconds
#  Total time in simulation          = 1.1379e+01 seconds
#    Time in transport only          = 1.0664e+01 seconds
#    Time in inactive batches        = 3.8724e+00 seconds
#    Time in active batches          = 7.5065e+00 seconds
#    Time synchronizing fission bank = 1.3600e-01 seconds
#      Sampling source sites         = 1.1536e-01 seconds
#      SEND/RECV source sites        = 2.0031e-02 seconds
#    Time accumulating tallies       = 4.7943e-01 seconds
#    Time writing statepoints        = 1.3382e-02 seconds
#  Total time for finalization       = 2.9358e-02 seconds
#  Total time elapsed                = 1.1675e+01 seconds
#  Calculation Rate (inactive)       = 258238.0 particles/second
#  Calculation Rate (active)         = 199826.0 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.96548 +/- 0.00084
#  k-effective (Track-length)  = 0.96553 +/- 0.00098
#  k-effective (Absorption)    = 0.96538 +/- 0.00081
#  Combined k-effective        = 0.96543 +/- 0.00069
#  Leakage Fraction            = 0.01018 +/- 0.00009

# %%
os.chdir('..')
if (not os.path.isdir('./p3_0')): #
    os.mkdir('./p3_0');
os.chdir('./p3_0');


mf.export_to_xml();
settings.export_to_xml();
gen_lattice(3.0);
# do without extra tallies for now.

p = openmc.Plot();
p.width = [200., 200.];
p.origin = [0.,0.,10.];
p.pixels = [1024,1024];
p.color_by = 'material';
p.colors = colors

openmc.plot_inline(p);

# %%
openmc.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                    | The OpenMC Monte Carlo Code
#          Copyright | 2011-2021 MIT and OpenMC contributors
#            License | https://docs.openmc.org/en/latest/license.html
#            Version | 0.12.1
#           Git SHA1 | d49e6ccb837685e399efdef8b29e46cdc693ccec
#          Date/Time | 2021-05-10 07:25:39
#     OpenMP Threads | 36
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading U238 from /home/sblair/OMC_DATA/endfb71_hdf5/U238.h5
#  Reading U235 from /home/sblair/OMC_DATA/endfb71_hdf5/U235.h5
#  Reading H1 from /home/sblair/OMC_DATA/endfb71_hdf5/H1.h5
#  Reading O16 from /home/sblair/OMC_DATA/endfb71_hdf5/O16.h5
#  Reading c_H_in_H2O from /home/sblair/OMC_DATA/endfb71_hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294.0 K
#  Maximum neutron data temperature: 294.0 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000.0 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1
#  Creating state point statepoint.250.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 2.5428e-01 seconds
#    Reading cross sections          = 2.3199e-01 seconds
#  Total time in simulation          = 1.0638e+01 seconds
#    Time in transport only          = 1.0223e+01 seconds
#    Time in inactive batches        = 3.6752e+00 seconds
#    Time in active batches          = 6.9629e+00 seconds
#    Time synchronizing fission bank = 1.3461e-01 seconds
#      Sampling source sites         = 1.1315e-01 seconds
#      SEND/RECV source sites        = 2.0841e-02 seconds
#    Time accumulating tallies       = 1.7185e-01 seconds
#    Time writing statepoints        = 6.4001e-03 seconds
#  Total time for finalization       = 3.0762e-02 seconds
#  Total time elapsed                = 1.0938e+01 seconds
#  Calculation Rate (inactive)       = 272095.0 particles/second
#  Calculation Rate (active)         = 215428.0 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.03743 +/- 0.00093
#  k-effective (Track-length)  = 1.03812 +/- 0.00113
#  k-effective (Absorption)    = 1.03857 +/- 0.00083
#  Combined k-effective        = 1.03813 +/- 0.00072
#  Leakage Fraction            = 0.01026 +/- 0.00009

# %%
os.chdir('..')
if (not os.path.isdir('./p3_2')): #
    os.mkdir('./p3_2');
os.chdir('./p3_2');


mf.export_to_xml();
settings.export_to_xml();
gen_lattice(3.2);
# do without extra tallies for now.

p = openmc.Plot();
p.width = [200., 200.];
p.origin = [0.,0.,10.];
p.pixels = [1024,1024];
p.color_by = 'material';
p.colors = colors

openmc.plot_inline(p);

# %%
openmc.run();
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                    | The OpenMC Monte Carlo Code
#          Copyright | 2011-2021 MIT and OpenMC contributors
#            License | https://docs.openmc.org/en/latest/license.html
#            Version | 0.12.1
#           Git SHA1 | d49e6ccb837685e399efdef8b29e46cdc693ccec
#          Date/Time | 2021-05-10 07:25:50
#     OpenMP Threads | 36
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading U238 from /home/sblair/OMC_DATA/endfb71_hdf5/U238.h5
#  Reading U235 from /home/sblair/OMC_DATA/endfb71_hdf5/U235.h5
#  Reading H1 from /home/sblair/OMC_DATA/endfb71_hdf5/H1.h5
#  Reading O16 from /home/sblair/OMC_DATA/endfb71_hdf5/O16.h5
#  Reading c_H_in_H2O from /home/sblair/OMC_DATA/endfb71_hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294.0 K
#  Maximum neutron data temperature: 294.0 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000.0 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.02701
#         2/1    1.06126
#         3/1    1.04899
#         4/1    1.04722
#         5/1    1.05799
#         6/1    1.06421
#         7/1    1.05868
#         8/1    1.04968
#         9/1    1.05812
#        10/1    1.00676
#        11/1    1.03005
#        12/1    1.04325
#        13/1    1.03939
#        14/1    1.04542
#        15/1    1.05529
#        16/1    1.04472
#        17/1    1.03496
#        18/1    1.04069
#        19/1    1.04293
#        20/1    1.05724
#        21/1    1.05581
#        22/1    1.02822
#        23/1    1.03320
#        24/1    1.03610
#        25/1    1.02485
#        26/1    1.04377
#        27/1    1.03120
#        28/1    1.03057
#        29/1    1.03226
#        30/1    1.02546
#        31/1    1.00455
#        32/1    1.02294
#        33/1    1.07311
#        34/1    1.02209
#        35/1    1.03420
#        36/1    1.03616
#        37/1    1.05914
#        38/1    1.03934
#        39/1    1.03828
#        40/1    1.04204
#        41/1    1.03647
#        42/1    1.02987
#        43/1    1.04529
#        44/1    1.05524
#        45/1    1.04782
#        46/1    1.04281
#        47/1    1.04607
#        48/1    1.02165
#        49/1    1.04592
#        50/1    1.02126
#        51/1    1.04208
#        52/1    1.04541
#        53/1    1.02345
#        54/1    1.04794
#        55/1    1.03393
#        56/1    1.04084
#        57/1    1.04420
#        58/1    1.06320
#        59/1    1.05297
#        60/1    1.02381
#        61/1    1.06420
#        62/1    1.04189
#        63/1    1.04445
#        64/1    1.04959
#        65/1    1.05108
#        66/1    1.03134
#        67/1    1.04659
#        68/1    1.04039
#       234/1    1.00679    1.02943 +/- 0.00110
#       235/1    1.04087    1.02952 +/- 0.00109
#       236/1    1.04362    1.02962 +/- 0.00109
#       237/1    1.01608    1.02952 +/- 0.00109
#       238/1    1.00806    1.02937 +/- 0.00109
#       239/1    1.03424    1.02940 +/- 0.00108
#       240/1    1.02933    1.02940 +/- 0.00108
#       241/1    1.02292    1.02935 +/- 0.00107
#       242/1    1.01337    1.02924 +/- 0.00107
#       243/1    1.01380    1.02913 +/- 0.00107
#       244/1    1.05046    1.02928 +/- 0.00107
#       245/1    1.04813    1.02941 +/- 0.00107
#       246/1    1.02153    1.02936 +/- 0.00106
#       247/1    1.02433    1.02932 +/- 0.00106
#       248/1    1.01405    1.02922 +/- 0.00105
#       249/1    1.03456    1.02926 +/- 0.00105
#       250/1    1.01951    1.02919 +/- 0.00104
#  Creating state point statepoint.250.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 2.5875e-01 seconds
#    Reading cross sections          = 2.3040e-01 seconds
#  Total time in simulation          = 1.1540e+01 seconds
#    Time in transport only          = 1.1030e+01 seconds
#    Time in inactive batches        = 3.9382e+00 seconds
#    Time in active batches          = 7.6015e+00 seconds
#    Time synchronizing fission bank = 1.5123e-01 seconds
#      Sampling source sites         = 1.3026e-01 seconds
#      SEND/RECV source sites        = 2.0351e-02 seconds
#    Time accumulating tallies       = 2.6283e-01 seconds
#    Time writing statepoints        = 6.2279e-03 seconds
#  Total time for finalization       = 3.0893e-02 seconds
#  Total time elapsed                = 1.1841e+01 seconds
#  Calculation Rate (inactive)       = 253926.0 particles/second
#  Calculation Rate (active)         = 197331.0 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.02977 +/- 0.00086
#  k-effective (Track-length)  = 1.02919 +/- 0.00104
#  k-effective (Absorption)    = 1.03088 +/- 0.00088
#  Combined k-effective        = 1.03022 +/- 0.00068
#  Leakage Fraction            = 0.01424 +/- 0.00012

# %%
os.chdir('../..')
if (not os.path.isdir('./partB')): #
    os.mkdir('./partB');
os.chdir('./partB');

# %% [markdown]
# ## Part B
# This will be the same as the 31x31 lattice except the core region will use heavy water and the reflector region will be graphite.

# %% [markdown]
# ### Materials

# %%
fuel = openmc.Material(name='fuel');
fuel.add_nuclide('U238',0.99,'wo');
fuel.add_nuclide('U235',0.01,'wo');
fuel.set_density('g/cm3',19.1);

mod = openmc.Material(name='mod');
mod.add_nuclide('H2',2,'ao');
mod.add_nuclide('O16',1,'ao');
mod.add_s_alpha_beta('c_D_in_D2O');
mod.set_density('g/cm3',1.105);

graph_refl = openmc.Material(name='graph_refl');
graph_refl.add_nuclide('C0',1,'ao');
graph_refl.add_s_alpha_beta('c_Graphite');
graph_refl.set_density('g/cm3',1.7);



mf = openmc.Materials();
mf += [fuel,mod,graph_refl];

mf.export_to_xml();

# %% [markdown]
# ### Geometry

# %%
def gen_lattice_hwg(l_pitch):
    #input lattice pitch
    
    n_pins = 31;
    pin_r = 1.; # cm, fuel pin radius
    
    fuel_pin = openmc.model.RightCircularCylinder([0.,0.,0.],100.,
                                              radius=pin_r,
                                              axis='z');

    fp_fuel = openmc.Cell(name='fuel');
    fp_fuel.fill = fuel;
    fp_fuel.region = -fuel_pin;

    fp_mod = openmc.Cell(name='mod in fuel');
    fp_mod.fill = mod;
    fp_mod.region = +fuel_pin;

    fp = openmc.Universe();
    fp.add_cells((fp_fuel,fp_mod));

    mod_cell = openmc.Cell();
    mod_cell.fill = mod;

    all_water = openmc.Universe();
    all_water.add_cell(mod_cell);
    
    core_bd = l_pitch*n_pins/2.
    core_area = openmc.model.RectangularParallelepiped(-core_bd,core_bd,-core_bd,core_bd,
                                                  0.,100.);

    lattice = openmc.RectLattice();
    lattice.dimension = [n_pins,n_pins];
    lattice.lower_left = [-core_bd,-core_bd];
    lattice.pitch = [l_pitch,l_pitch];

    lattice.universes = [[ fp for i in range(n_pins)]for j in range(n_pins)];
           

    lattice.outer = all_water;

    core_cell = openmc.Cell();
    core_cell.fill = lattice;
    core_cell.region = -core_area;

    refl_cell = openmc.Cell();
    refl_cell.fill = graph_refl;
    refl_cell.region = +core_area & -core_tank;

    root = openmc.Universe();
    root.add_cells([core_cell,refl_cell]);

    g = openmc.Geometry();
    g.root_universe = root;
    g.export_to_xml();
    
    
    fuel_cell_filter = openmc.DistribcellFilter([fp_fuel]);
    mod_in_fuel_filter = openmc.DistribcellFilter([fp_mod]);
    rfl_cell_filter = openmc.CellFilter([refl_cell]);

    tallies = openmc.Tallies()

    abs_fuel = openmc.Tally(name='abs. fuel');
    abs_fuel.filters = [energy_filter,fuel_cell_filter];
    abs_fuel.scores = ['absorption'];
    abs_fuel.nuclides = ['U235','U238'];
    tallies.append(abs_fuel);

    abs_mod_ref = openmc.Tally(name='abs. mod refl');
    abs_mod_ref.filters = [energy_filter,rfl_cell_filter];
    abs_mod_ref.nuclides = ['C0'];
    abs_mod_ref.scores = ['absorption'];
    tallies.append(abs_mod_ref);

    abs_mod_fuel = openmc.Tally(name='abs. mod fuel');
    abs_mod_fuel.filters = [energy_filter,mod_in_fuel_filter];
    abs_mod_fuel.nuclides = ['H2','O16'];
    abs_mod_fuel.scores = ['absorption'];
    tallies.append(abs_mod_fuel);


    t_fiss = openmc.Tally(name='fission tally');
    t_fiss.filters = [energy_filter,fuel_cell_filter];
    t_fiss.nuclides = ['U235','U238'];
    t_fiss.scores = ['fission','nu-fission'];
    tallies.append(t_fiss);

    tallies.export_to_xml();

# %%
gen_lattice_hwg(3.2); #lattice with heavy water and graphite, 3.2 cm pitch

# %%
settings.export_to_xml();

# %%
colors = {}
colors[mod] = 'blue';
colors[fuel] = 'yellow';
colors[graph_refl] = 'gray';

# %%
p = openmc.Plot();
p.width = [200., 200.];
p.origin = [0.,0.,10.];
p.pixels = [1024,1024];
p.color_by = 'material';
p.colors = colors

openmc.plot_inline(p);

# %%
openmc.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                    | The OpenMC Monte Carlo Code
#          Copyright | 2011-2021 MIT and OpenMC contributors
#            License | https://docs.openmc.org/en/latest/license.html
#            Version | 0.12.1
#           Git SHA1 | d49e6ccb837685e399efdef8b29e46cdc693ccec
#          Date/Time | 2021-05-10 07:26:15
#     OpenMP Threads | 36
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading U238 from /home/sblair/OMC_DATA/endfb71_hdf5/U238.h5
#  Reading U235 from /home/sblair/OMC_DATA/endfb71_hdf5/U235.h5
#  Reading H2 from /home/sblair/OMC_DATA/endfb71_hdf5/H2.h5
#  Reading O16 from /home/sblair/OMC_DATA/endfb71_hdf5/O16.h5
#  Reading C0 from /home/sblair/OMC_DATA/endfb71_hdf5/C0.h5
#  Reading c_D_in_D2O from /home/sblair/OMC_DATA/endfb71_hdf5/c_D_in_D2O.h5
#  Reading c_Graphite from /home/sblair/OMC_DATA/endfb71_hdf5/c_Graphite.h5
#  Minimum neutron data temperature: 294.0 K
#  Maximum neutron data temperature: 294.0 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000.0 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0
#  Creating state point statepoint.250.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.4540e-01 seconds
#    Reading cross sections          = 3.1415e-01 seconds
#  Total time in simulation          = 1.1696e+01 seconds
#    Time in transport only          = 1.1027e+01 seconds
#    Time in inactive batches        = 3.7576e+00 seconds
#    Time in active batches          = 7.9383e+00 seconds
#    Time synchronizing fission bank = 1.3686e-01 seconds
#      Sampling source sites         = 1.1628e-01 seconds
#      SEND/RECV source sites        = 1.9940e-02 seconds
#    Time accumulating tallies       = 4.2519e-01 seconds
#    Time writing statepoints        = 6.2157e-03 seconds
#  Total time for finalization       = 3.1690e-02 seconds
#  Total time elapsed                = 1.2085e+01 seconds
#  Calculation Rate (inactive)       = 266124.0 particles/second
#  Calculation Rate (active)         = 188956.0 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.60929 +/- 0.00072
#  k-effective (Track-length)  = 0.60941 +/- 0.00079
#  k-effective (Absorption)    = 0.60807 +/- 0.00089
#  Combined k-effective        = 0.60890 +/- 0.00066
#  Leakage Fraction            = 0.13230 +/- 0.00035

# %%
os.chdir('..')
if (not os.path.isdir('./partC')): #
    os.mkdir('./partC');
os.chdir('./partC');

# %% [markdown]
# ## Part C
# In this iteration of the analysis we increase the overall size of the reactor tank to 300 cm and, using the same 31x31 lattice, vary the pitch from 4cm to 12cm noting the change of $k_{\text{eff}}$ along the way.

# %% [markdown]
# ### Materials, Geometry, and Tallies
# So - a few small changes are required but I thought it would be nice to have all of the relevent bits of code all together (for once).  T

# %%
fuel = openmc.Material(name='fuel');
fuel.add_nuclide('U238',0.99,'wo');
fuel.add_nuclide('U235',0.01,'wo');
fuel.set_density('g/cm3',19.1);

mod = openmc.Material(name='mod');
mod.add_nuclide('H2',2,'ao');
mod.add_nuclide('O16',1,'ao');
mod.add_s_alpha_beta('c_D_in_D2O');
mod.set_density('g/cm3',1.105);



mf = openmc.Materials();
mf += [fuel,mod];

mf.export_to_xml();


core_tank = openmc.model.RightCircularCylinder([0.,0.,-5.],
                                              150.,radius=300.,
                                               axis='z',
                                              boundary_type='vacuum');

core_cell = openmc.Cell();
core_cell.fill = h_core;
core_cell.region = -core_tank;

root_universe = openmc.Universe();
root_universe.add_cells([core_cell]);

geometry = openmc.Geometry(root_universe);
geometry.export_to_xml();


def gen_lattice_hw(l_pitch):
    #input lattice pitch
    
    n_pins = 31;
    pin_r = 1.; # cm, fuel pin radius
    
    fuel_pin = openmc.model.RightCircularCylinder([0.,0.,0.],100.,
                                              radius=pin_r,
                                              axis='z');

    fp_fuel = openmc.Cell(name='fuel');
    fp_fuel.fill = fuel;
    fp_fuel.region = -fuel_pin;

    fp_mod = openmc.Cell(name='mod in fuel');
    fp_mod.fill = mod;
    fp_mod.region = +fuel_pin;

    fp = openmc.Universe();
    fp.add_cells((fp_fuel,fp_mod));

    mod_cell = openmc.Cell();
    mod_cell.fill = mod;

    all_water = openmc.Universe();
    all_water.add_cell(mod_cell);
    
    core_bd = l_pitch*n_pins/2.
    core_area = openmc.model.RectangularParallelepiped(-core_bd,core_bd,-core_bd,core_bd,
                                                  0.,100.);

    lattice = openmc.RectLattice();
    lattice.dimension = [n_pins,n_pins];
    lattice.lower_left = [-core_bd,-core_bd];
    lattice.pitch = [l_pitch,l_pitch];

    lattice.universes = [[ fp for i in range(n_pins)]for j in range(n_pins)];
           

    lattice.outer = all_water;

    core_cell = openmc.Cell();
    core_cell.fill = lattice;
    core_cell.region = -core_area;

    refl_cell = openmc.Cell();
    refl_cell.fill = mod;
    refl_cell.region = +core_area & -core_tank;

    root = openmc.Universe();
    root.add_cells([core_cell,refl_cell]);

    g = openmc.Geometry();
    g.root_universe = root;
    g.export_to_xml();
    
    
    fuel_cell_filter = openmc.DistribcellFilter([fp_fuel]);
    mod_in_fuel_filter = openmc.DistribcellFilter([fp_mod]);
    rfl_cell_filter = openmc.CellFilter([refl_cell]);

    tallies = openmc.Tallies()

    abs_fuel = openmc.Tally(name='abs. fuel');
    abs_fuel.filters = [energy_filter,fuel_cell_filter];
    abs_fuel.scores = ['absorption'];
    abs_fuel.nuclides = ['U235','U238'];
    tallies.append(abs_fuel);

    abs_mod_ref = openmc.Tally(name='abs. mod refl');
    abs_mod_ref.filters = [energy_filter,rfl_cell_filter];
    abs_mod_ref.nuclides = ['H2','O16'];
    abs_mod_ref.scores = ['absorption'];
    tallies.append(abs_mod_ref);

    abs_mod_fuel = openmc.Tally(name='abs. mod fuel');
    abs_mod_fuel.filters = [energy_filter,mod_in_fuel_filter];
    abs_mod_fuel.nuclides = ['H2','O16'];
    abs_mod_fuel.scores = ['absorption'];
    tallies.append(abs_mod_fuel);


    t_fiss = openmc.Tally(name='fission tally');
    t_fiss.filters = [energy_filter,fuel_cell_filter];
    t_fiss.nuclides = ['U235','U238'];
    t_fiss.scores = ['fission','nu-fission'];
    tallies.append(t_fiss);

    tallies.export_to_xml();

# %%
gen_lattice_hw(4.0);

p = openmc.Plot();
p.width = [400., 400.];
p.origin = [0.,0.,10.];
p.pixels = [1024,1024];
p.color_by = 'material';
p.colors = colors

openmc.plot_inline(p);
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-73-3841e7f74c0d> in <module>
#       8 p.colors = colors
#       9
# ---> 10 openmc.plot_inline(p);
#
# ~/anaconda3/envs/omc_latest/lib/python3.9/site-packages/openmc/executor.py in plot_inline(plots, openmc_exec, cwd, convert_exec)
#      93
#      94     # Run OpenMC in geometry plotting mode
# ---> 95     plot_geometry(False, openmc_exec, cwd)
#      96
#      97     images = []
#
# ~/anaconda3/envs/omc_latest/lib/python3.9/site-packages/openmc/executor.py in plot_geometry(output, openmc_exec, cwd)
#      57
#      58     """
# ---> 59     _run([openmc_exec, '-p'], output, cwd)
#      60
#      61
#
# ~/anaconda3/envs/omc_latest/lib/python3.9/site-packages/openmc/executor.py in _run(args, output, cwd)
#      36         error_msg = ' '.join(error_msg.split())
#      37
# ---> 38         raise RuntimeError(error_msg)
#      39
#      40
#
# RuntimeError: Could not find material 4 specified in plot 9
